# %% [markdown]
# ## install libs

# %%
# %%capture
# !pip install datasets
# !pip install -U huggingface_hub

# %%
# login to HF HUB
from huggingface_hub import login
from google.colab import userdata

login(userdata.get('HF_TOKEN'))
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## load dataset into DF

# %%
from datasets import load_dataset

dataset = load_dataset("the-french-artist/hatvp_declarations_xml_plus_json", split='train')

# %%
dataset
# Out:
# Dataset({
#     features: ['xml_sha1', 'declaration_xml', 'declaration_json', 'extracted_text'],
#     num_rows: 10944
# })

# %%
import pandas as pd

declaration_df = dataset.to_pandas()

# %%
del declaration_df['extracted_text']

# %%
declaration_df.head()
# Out:
#                                    xml_sha1  \
# 0  0a0a9f2a6772942557ab5355d76af442f8f65e01
# 1  0a0a9f2a6772942557ab5355d76af442f8f65e01
# 2  0a0a9f2a6772942557ab5355d76af442f8f65e01
# 3  0a0a9f2a6772942557ab5355d76af442f8f65e01
# 4  0a0a9f2a6772942557ab5355d76af442f8f65e01
#
#                                      declaration_xml  \
# 0  <declaration><dateDepot>11/07/2022 15:40:13</d...
# 1  <declaration><dateDepot>27/11/2022 18:18:23</d...
# 2  <declaration><dateDepot>19/08/2022 10:08:23</d...
# 3  <declaration><dateDepot>04/10/2022 17:22:07</d...
# 4  <declaration><dateDepot>20/09/2021 13:41:36</d...
#
#                                     declaration_json
# 0  {"declaration": {"dateDepot": "11/07/2022 15:4...
# 1  {"declaration": {"dateDepot": "27/11/2022 18:1...
# 2  {"declaration": {"dateDepot": "19/08/2022 10:0...
# 3  {"declaration": {"dateDepot": "04/10/2022 17:2...
# 4  {"declaration": {"dateDepot": "20/09/2021 13:4...

# %% [markdown]
# ## test a single declaration

# %%
first_test = declaration_df.head().declaration_json.to_list()[0]

# %%
import json

parsed_declaration = json.loads(first_test)
parsed_declaration
# Out:
# {'declaration': {'dateDepot': '11/07/2022 15:40:13',
#   'uuid': '4344aaa1-874d-4e6d-9b1a-45f7725b710c',
#   'origine': 'ADEL',
#   'complete': 'true',
#   'attachedFiles': {'attachedFiles': {'fileName': 'VUE_PDF_DU_RECEPISSE_DU_DEPOT_XML',
#     'serverFileName': None,
#     'base64EncodedContent': ''}},
#   'declarationVersion': '20171221',
#   'activConsultantDto': {'neant': 'true'},
#   'activProfCinqDerniereDto': {'neant': 'true'},
#   'activProfConjointDto': {'items': {'items': {'motif': {'id': 'CREATION',
#       'label': None},
#      'commentaire': None,
#      'nomConjoint': '[Données non publiées]',
#      'employeurConjoint': 'CENTRE HOSPITALIER DU HAUT-BUGEY',
#      'activiteProf': 'Infirmière'}},
#    'neant': 'false'},
#   'fonctionBenevoleDto': {'neant': 'true'},
#   'mandatElectifDto': {'items': {'items': [{'motif': {'id': 'CREATION',
#        'label': None},
#       'commentaire': 'REVENUS NETS IMPOSABLES        [Données non publiées]',
#       'descriptionMandat': 'DEPUTE',
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2017', 'montant': '67\u202f047'},
#          {'annee': '2018', 'montant': '71\u202f042'},
#          {'annee': '2019', 'montant': '71\u202f105'},
#          {'annee': '2020', 'montant': '70\u202f773'},
#          {'annee': '2021', 'montant': '70\u202f676'},
#          {'annee': '2022', 'montant': '27\u202f289'}]}},
#       'dateDebut': '01/2017',
#       'dateFin': None},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': 'REVENUS NETS IMPOSABLES        [Données non publiées]',
#       'descriptionMandat': 'PRESIDENT DU DEPARTEMENT 01',
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2015', 'montant': '16865'},
#          {'annee': '2016', 'montant': '23035'},
#          {'annee': '2017', 'montant': '20120'}]}},
#       'dateDebut': '04/2015',
#       'dateFin': '07/2017'},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': "J'ai été élu président de groupe LR le 6 Novembre 2019. Cette fonction n'octroie aucune rémunération supplémentaire",
#       'descriptionMandat': "Président du Groupe Les Républicains à l'Assemblée nationale",
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2019', 'montant': '0'},
#          {'annee': '2020', 'montant': '0'},
#          {'annee': '2021', 'montant': '0'},
#          {'annee': '2022', 'montant': '0'}]}},
#       'dateDebut': '11/2019',
#       'dateFin': '05/2022'},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': '[Données non publiées]',
#       'descriptionMandat': 'CONSEILLER DEPARTEMENTAL',
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2017', 'montant': '28\u202f007'},
#          {'annee': '2018', 'montant': '24\u202f201'},
#          {'annee': '2019', 'montant': '16\u202f386'},
#          {'annee': '2020', 'montant': '16\u202f386'},
#          {'annee': '2021', 'montant': '16\u202f384'},
#          {'annee': '2022', 'montant': '6\u202f827'}]}},
#       'dateDebut': '07/2017',
#       'dateFin': None},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': None,
#       'descriptionMandat': "Département de l'Ain - Président du Groupe majoritaire l'Ain de toute nos forces",
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2017', 'montant': '0'},
#          {'annee': '2018', 'montant': '0'},
#          {'annee': '2019', 'montant': '0'},
#          {'annee': '2020', 'montant': '0'},
#          {'annee': '2021', 'montant': '0'},
#          {'annee': '2022', 'montant': '0'}]}},
#       'dateDebut': '07/2017',
#       'dateFin': None}]},
#    'neant': 'false'},
#   'participationDirigeantDto': {'items': {'items': [{'motif': {'id': 'CREATION',
#        'label': None},
#       'commentaire': 'Président du SDIS 01. Activité arrêtée depuis ma démission de la présidence du département en juillet 2017',
#       'nomSociete': 'SDIS 01',
#       'activite': "Service départemental d'incendie et de secours",
#       'remuneration': {'brutNet': 'Brut',
#        'montant': {'montant': [{'annee': '2015', 'montant': '0'},
#          {'annee': '2016', 'montant': '0'},
#          {'annee': '2017', 'montant': '0'}]}},
#       'dateDebut': '04/2015',
#       'dateFin': '07/2017'},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': "Président de l'association AINTOURISME qui développe et promeut la politique touristique du Département de l'Ain.",
#       'nomSociete': 'ASSOCIATION AINTOURISME',
#       'activite': "Président d'Aintourisme qui a pour objet la politique touristique du Département",
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2017', 'montant': '0'},
#          {'annee': '2018', 'montant': '0'},
#          {'annee': '2019', 'montant': '0'},
#          {'annee': '2020', 'montant': '0'},
#          {'annee': '2021', 'montant': '0'},
#          {'annee': '2022', 'montant': '0'}]}},
#       'dateDebut': '07/2017',
#       'dateFin': None},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': "Mon élection comme président du groupe LR à l'assemblée nationale date du 6 Novembre 2019. Ce titre n'octroie pas une rémunération supplémentaire.",
#       'nomSociete': 'Assemblée nationale - Groupe Les Républicains -',
#       'activite': "Président du Groupe Les Républicains à l'Assemblée nationale",
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2019', 'montant': '0'},
#          {'annee': '2020', 'montant': '0'},
#          {'annee': '2021', 'montant': '0'},
#          {'annee': '2022', 'montant': '0'}]}},
#       'dateDebut': '11/2019',
#       'dateFin': '05/2022'},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': "Promotion du patrimoine culinaire et gastronomique du Département de l'Ain",
#       'nomSociete': "ASSOCIATION SAVEURS DE L'AIN",
#       'activite': "Président de l'association Saveurs de l'Ain qui a pour objet de promouvoir la gastronomie de notre Département",
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2019', 'montant': '0'},
#          {'annee': '2020', 'montant': '0'},
#          {'annee': '2021', 'montant': '0'},
#          {'annee': '2022', 'montant': '0'}]}},
#       'dateDebut': '05/2019',
#       'dateFin': None},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': "Association - parti politique Création Décembre 2018 Nous avons changé de noms à plusieurs reprises : d'abord la France des territoires, puis Dans l'Action puis Les Amis de Damien Abad, nouveau nom depuis Septembre 2020.",
#       'nomSociete': 'Association Les Amis de Damien Abad',
#       'activite': "Président de l'association Les Amis de Damien Abad",
#       'remuneration': {'brutNet': 'Net',
#        'montant': {'montant': [{'annee': '2018', 'montant': '0'},
#          {'annee': '2019', 'montant': '0'},
#          {'annee': '2020', 'montant': '0'},
#          {'annee': '2021', 'montant': '0'},
#          {'annee': '2022', 'montant': '0'}]}},
#       'dateDebut': '12/2018',
#       'dateFin': None}]},
#    'neant': 'false'},
#   'participationFinanciereDto': {'items': {'items': [{'motif': {'id': 'CREATION',
#        'label': None},
#       'commentaire': '[Données non publiées]',
#       'nomSociete': 'ORANGE',
#       'evaluation': '877',
#       'remuneration': 'néant',
#       'capitalDetenu': None,
#       'nombreParts': '83',
#       'actiConseil': 'Non'},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': '[Données non publiées]',
#       'nomSociete': 'CREDIT AGRICOLE SA',
#       'evaluation': '2910',
#       'remuneration': 'néant',
#       'capitalDetenu': None,
#       'nombreParts': '341',
#       'actiConseil': 'Non'},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': '[Données non publiées]',
#       'nomSociete': 'AIRBUS',
#       'evaluation': '1929',
#       'remuneration': 'NEANT',
#       'capitalDetenu': None,
#       'nombreParts': '20',
#       'actiConseil': 'Non'},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': '[Données non publiées]',
#       'nomSociete': "L'OREAL",
#       'evaluation': '6552',
#       'remuneration': 'NEANT',
#       'capitalDetenu': None,
#       'nombreParts': '20',
#       'actiConseil': 'Non'}]},
#    'neant': 'false'},
#   'activCollaborateursDto': {'items': {'items': [{'motif': {'id': 'CREATION',
#        'label': None},
#       'commentaire': None,
#       'nom': 'LOPES MAGNUSON',
#       'employeur': 'Néant',
#       'descriptionActivite': 'Assistant fonctionnel'},
#      {'motif': {'id': 'CREATION', 'label': None},
#       'commentaire': None,
#       'nom': 'FOUGNIES REBECCA',
#       'employeur': 'Néant',
#       'descriptionActivite': 'Assistante parlementaire locale'}]},
#    'neant': 'false'},
#   'observationInteretDto': {'items': {'items': {'motif': {'id': 'CREATION',
#       'label': None},
#      'commentaire': None,
#      'contenu': 'mon équipe de collaborateurs parlementaires sera complétée dans les prochaines semaines'}},
#    'neant': 'false'},
#   'general': {'typeDeclaration': {'id': 'DIA',
#     'label': "Déclaration d'intérêts et d'activités"},
#    'mandat': {'label': 'Député ou sénateur'},
#    'qualiteMandat': {'typeMandat': 'Député',
#     'codCategorieMandat': 'PAR',
#     'nomCategorieMandat': 'Député ou sénateur',
#     'codTypeMandatFichier': 'depute',
#     'labelTypeMandat': 'Député',
#     'labelOrgane': "Département d'élection",
#     'codeListeOrgane': 'ZEP'},
#    'organe': {'codeOrgane': '01',
#     'codeListeOrgane': 'ZEP',
#     'nomListeOrgane': "Zones d'élection des parlementaires",
#     'labelOrgane': 'Ain(01)',
#     'labelDeclaration': None,
#     'organeParent': None},
#    'qualiteDeclarant': None,
#    'qualiteDeclarantForPDF': 'Député/Ain(01)',
#    'dateDebutMandat': '19/06/2022',
#    'dateFinMandat': None,
#    'dateDernDeclar': None,
#    'regimeMatrimonial': None,
#    'regimeMatrimonialComments': None,
#    'nomSociete': None,
#    'nomSocieteMere': None,
#    'chiffreAffaire': None,
#    'nbLogements': None,
#    'declarationModificative': 'false',
#    'etablissement': None,
#    'declarant': {'civilite': 'M.',
#     'nom': 'ABAD',
#     'prenom': 'DAMIEN',
#     'email': '[Données non publiées]',
#     'dateNaissance': '05/04/1980',
#     'pieceIdentite': None,
#     'telephoneDec': '[Données non publiées]',
#     'adresseDec': {'voie': '[Données non publiées]',
#      'complement': '[Données non publiées]',
#      'codePostal': '[Données non publiées]',
#      'ville': '[Données non publiées]',
#      'pays': '[Données non publiées]'}}}}}

# %%
declaration = parsed_declaration.get('declaration')
stock_data_list = None
# safely travel down to stock data list
if declaration is not None:
  participationFinanciereDto = declaration.get('participationFinanciereDto')
  if participationFinanciereDto is not None:
    participationFinanciereDto_items = participationFinanciereDto.get('items')
    if participationFinanciereDto_items is not None:
      stock_data_list = participationFinanciereDto_items.get('items')

stock_data_list
# Out:
# [{'commentaire': '[Données non publiées]',
#   'nomSociete': 'ORANGE',
#   'evaluation': '877',
#   'remuneration': 'néant',
#   'capitalDetenu': None,
#   'nombreParts': '83',
#   'actiConseil': 'Non'},
#  {'commentaire': '[Données non publiées]',
#   'nomSociete': 'CREDIT AGRICOLE SA',
#   'evaluation': '2910',
#   'remuneration': 'néant',
#   'capitalDetenu': None,
#   'nombreParts': '341',
#   'actiConseil': 'Non'},
#  {'commentaire': '[Données non publiées]',
#   'nomSociete': 'AIRBUS',
#   'evaluation': '1929',
#   'remuneration': 'NEANT',
#   'capitalDetenu': None,
#   'nombreParts': '20',
#   'actiConseil': 'Non'},
#  {'commentaire': '[Données non publiées]',
#   'nomSociete': "L'OREAL",
#   'evaluation': '6552',
#   'remuneration': 'NEANT',
#   'capitalDetenu': None,
#   'nombreParts': '20',
#   'actiConseil': 'Non'}]

# %%
stock_data_list[0]
# Out:
# {'motif': {'id': 'CREATION', 'label': None},
#  'commentaire': '[Données non publiées]',
#  'nomSociete': 'ORANGE',
#  'evaluation': '877',
#  'remuneration': 'néant',
#  'capitalDetenu': None,
#  'nombreParts': '83',
#  'actiConseil': 'Non'}

# %%
for curr_stock_data in stock_data_list:
  # remove the "motif" attribute that is not interesting
  if curr_stock_data.get('motif') is not None:
    del curr_stock_data['motif']

stock_data_df = pd.DataFrame(stock_data_list)
stock_data_df
# Out:
#               commentaire          nomSociete evaluation remuneration  \
# 0  [Données non publiées]              ORANGE        877        néant
# 1  [Données non publiées]  CREDIT AGRICOLE SA       2910        néant
# 2  [Données non publiées]              AIRBUS       1929        NEANT
# 3  [Données non publiées]             L'OREAL       6552        NEANT
#
#   capitalDetenu nombreParts actiConseil
# 0          None          83         Non
# 1          None         341         Non
# 2          None          20         Non
# 3          None          20         Non

# %% [markdown]
# ### Make a function to get a DF of all stocks for a given declaration (or None if no stocks)

# %%
import json


def get_stock_df(string_declaration):
  parsed_declaration = json.loads(string_declaration)
  declaration = parsed_declaration.get('declaration')
  stock_data_list = None
  # safely travel down to stock data list
  if declaration is not None:
    participationFinanciereDto = declaration.get('participationFinanciereDto')
    if participationFinanciereDto is not None:
      participationFinanciereDto_items = participationFinanciereDto.get('items')
      if participationFinanciereDto_items is not None:
        stock_data_list = participationFinanciereDto_items.get('items')

  # early return if no stocks are found in the current declaration
  if stock_data_list is None:
    return None

  if not isinstance(stock_data_list, list):
    stock_data_list = [stock_data_list]

  # remove the "motif" attribute that is not interesting
  for curr_stock_data in stock_data_list:
    if curr_stock_data.get('motif') is not None:
      del curr_stock_data['motif']

  # make a dataframe from the list of dicts
  stocks_df =  pd.DataFrame(stock_data_list)

  # add some ID features
  stocks_df.insert(0, 'declarant_birthdate', parsed_declaration['declaration']['general']['declarant']['dateNaissance'])
  stocks_df.insert(0, 'declarant_surname', parsed_declaration['declaration']['general']['declarant']['prenom'])
  stocks_df.insert(0, 'declarant_name', parsed_declaration['declaration']['general']['declarant']['nom'])
  stocks_df.insert(0, 'declaration_publication_date', parsed_declaration['declaration']['dateDepot'])
  stocks_df.insert(0, 'declaration_uuid', parsed_declaration['declaration']['uuid'])

  # move "commentaire" column to the end
  commentaires = stocks_df.pop('commentaire')
  stocks_df.insert(len(stocks_df.columns), 'commentaire', commentaires)


  return stocks_df

# %%
get_stock_df(first_test)
# Out:
#                        declaration_uuid declaration_publication_date  \
# 0  4344aaa1-874d-4e6d-9b1a-45f7725b710c          11/07/2022 15:40:13
# 1  4344aaa1-874d-4e6d-9b1a-45f7725b710c          11/07/2022 15:40:13
# 2  4344aaa1-874d-4e6d-9b1a-45f7725b710c          11/07/2022 15:40:13
# 3  4344aaa1-874d-4e6d-9b1a-45f7725b710c          11/07/2022 15:40:13
#
#   declarant_name declarant_surname declarant_birthdate          nomSociete  \
# 0           ABAD            DAMIEN          05/04/1980              ORANGE
# 1           ABAD            DAMIEN          05/04/1980  CREDIT AGRICOLE SA
# 2           ABAD            DAMIEN          05/04/1980              AIRBUS
# 3           ABAD            DAMIEN          05/04/1980             L'OREAL
#
#   evaluation remuneration capitalDetenu nombreParts actiConseil  \
# 0        877        néant          None          83         Non
# 1       2910        néant          None         341         Non
# 2       1929        NEANT          None          20         Non
# 3       6552        NEANT          None          20         Non
#
#               commentaire
# 0  [Données non publiées]
# 1  [Données non publiées]
# 2  [Données non publiées]
# 3  [Données non publiées]

# %% [markdown]
# ## Perform extraction on complete dataset
#
# We will collect a list of dataframes, one dataframe per declaration, and then concatenate them.

# %%
string_json_list = declaration_df.declaration_json.to_list()

# %%
from tqdm.auto import tqdm

stock_df_list = []
for curr_json_declaration in tqdm(string_json_list):
  stock_df_list.append(get_stock_df(curr_json_declaration))
# Out:
#   0%|          | 0/10944 [00:00<?, ?it/s]

# %% [markdown]
# ## Format and clean dataset

# %% [markdown]
# ### Concat list of DFs into a single DF

# %%
complete_stocks_df = pd.concat(stock_df_list)
complete_stocks_df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ### Set name and surname to upper chars

# %%
complete_stocks_df['declarant_name'] = complete_stocks_df['declarant_name'].str.upper()
complete_stocks_df['declarant_surname'] = complete_stocks_df['declarant_surname'].str.upper()
complete_stocks_df.head()
# Out:
#                            declaration_uuid declaration_publication_date  \
# 0      4344aaa1-874d-4e6d-9b1a-45f7725b710c          11/07/2022 15:40:13
# 1      4344aaa1-874d-4e6d-9b1a-45f7725b710c          11/07/2022 15:40:13
# 2      4344aaa1-874d-4e6d-9b1a-45f7725b710c          11/07/2022 15:40:13
# 3      4344aaa1-874d-4e6d-9b1a-45f7725b710c          11/07/2022 15:40:13
# 4      fa8d18ec-0db9-4a39-b1f4-caba0c31329b          27/11/2022 18:18:23
# ...                                     ...                          ...
# 11055  19140875-1488-43e7-95a7-63d0b7212a19          25/06/2021 13:29:08
# 11056  19140875-1488-43e7-95a7-63d0b7212a19          25/06/2021 13:29:08
# 11057  19140875-1488-43e7-95a7-63d0b7212a19          25/06/2021 13:29:08
# 11058  19140875-1488-43e7-95a7-63d0b7212a19          25/06/2021 13:29:08
# 11059  19140875-1488-43e7-95a7-63d0b7212a19          25/06/2021 13:29:08
#
#       declarant_name declarant_surname declarant_birthdate  \
# 0               ABAD            DAMIEN          05/04/1980
# 1               ABAD            DAMIEN          05/04/1980
# 2               ABAD            DAMIEN          05/04/1980
# 3               ABAD            DAMIEN          05/04/1980
# 4               ABAD            DAMIEN          05/04/1980
# ...              ...               ...                 ...
# 11055          ZUILI           NICOLAS          08/03/1965
# 11056          ZUILI           NICOLAS          08/03/1965
# 11057          ZUILI           NICOLAS          08/03/1965
# 11058          ZUILI           NICOLAS          08/03/1965
# 11059          ZUILI           NICOLAS          08/03/1965
#
#                nomSociete evaluation remuneration capitalDetenu nombreParts  \
# 0                  ORANGE        877        néant          None          83
# 1      CREDIT AGRICOLE SA       2910        néant          None         341
# 2                  AIRBUS       1929        NEANT          None          20
# 3                 L'OREAL       6552        NEANT          None          20
# 4                  ORANGE        877        néant          None          83
# ...                   ...        ...          ...           ...         ...
# 11055                 AXA       2173            0          None         100
# 11056         BNP PARIBAS      10820            0          None         200
# 11057             RENAULT       7073            0          None         200
# 11058        SAINT GOBAIN      11238            0          None         200
# 11059     UNIBAIL RODAMCO       7991            0          None         100
#
#       actiConseil             commentaire nomOrganisationConseil
# 0             Non  [Données non publiées]                    NaN
# 1             Non  [Données non publiées]                    NaN
# 2             Non  [Données non publiées]                    NaN
# 3             Non  [Données non publiées]                    NaN
# 4             Non  [Données non publiées]                    NaN
# ...           ...                     ...                    ...
# 11055         NaN        COMPTE TITRE CDN                    NaN
# 11056         NaN       COMPTE TITRES CDN                    NaN
# 11057         NaN        COMPTE TITRE CDN                    NaN
# 11058         NaN       COMPTE TITRES CDN                    NaN
# 11059         NaN       COMPTE TITRES CDN                    NaN
#
# [11060 rows x 13 columns]

# %% [markdown]
# ### Convert data column to Datetime format

# %%
complete_stocks_df['declaration_publication_date'] = pd.to_datetime(complete_stocks_df['declaration_publication_date'], format='%d/%m/%Y %H:%M:%S')

# %% [markdown]
# ### Create a unique ID for each declarant

# %%
# Combine 'declarant_name' and 'declarant_surname' and 'declarant_birthdate' to create a unique identifier for each declarant
complete_stocks_df['declarant_unique_id'] = complete_stocks_df['declarant_name'] + '-' + complete_stocks_df['declarant_surname'] +'-'+ complete_stocks_df['declarant_birthdate']
complete_stocks_df.head()
# Out:
#                        declaration_uuid declaration_publication_date  \
# 0  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
# 1  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
# 2  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
# 3  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
# 4  fa8d18ec-0db9-4a39-b1f4-caba0c31329b          2022-11-27 18:18:23
#
#   declarant_name declarant_surname declarant_birthdate          nomSociete  \
# 0           ABAD            DAMIEN          05/04/1980              ORANGE
# 1           ABAD            DAMIEN          05/04/1980  CREDIT AGRICOLE SA
# 2           ABAD            DAMIEN          05/04/1980              AIRBUS
# 3           ABAD            DAMIEN          05/04/1980             L'OREAL
# 4           ABAD            DAMIEN          05/04/1980              ORANGE
#
#   evaluation remuneration capitalDetenu nombreParts actiConseil  \
# 0        877        néant          None          83         Non
# 1       2910        néant          None         341         Non
# 2       1929        NEANT          None          20         Non
# 3       6552        NEANT          None          20         Non
# 4        877        néant          None          83         Non
#
#               commentaire nomOrganisationConseil     declarant_unique_id
# 0  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980
# 1  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980
# 2  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980
# 3  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980
# 4  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980

# %% [markdown]
# We count the number of UUID to see how many declarations some declarants have:

# %%
# Group by the full name of the declarant and count unique 'declaration_version' values
unique_versions_per_declarant = complete_stocks_df.groupby('declarant_unique_id')['declaration_uuid'].nunique()
unique_versions_per_declarant.to_frame().sort_values('declaration_uuid', ascending=False)
# Out:
#                               declaration_uuid
# declarant_unique_id
# LISNARD-DAVID-02/02/1969                    21
# VIAUD-JÉRÔME-13/09/1977                     12
# KLINKERT-BRIGITTE-22/07/1956                 9
# LEVY-ARIEL-27/02/1990                        9
# BLANC-ETIENNE-29/08/1954                     9
# ...                                        ...
# GÉRY-FABIEN-07/06/1972                       1
# GYGES-CHRISTOPHER-18/04/1984                 1
# GUYON-SÉBASTIEN-26/12/1979                   1
# GUYOD-STEPHANE-22/05/1970                    1
# ZUILI-NICOLAS-08/03/1965                     1
#
# [1904 rows x 1 columns]

# %% [markdown]
# Lets check the top declarant by number of unique declarations:

# %%
complete_stocks_df[complete_stocks_df['declarant_name'] == 'LISNARD'].sort_values('declaration_publication_date')
# Out:
#                           declaration_uuid declaration_publication_date  \
# 6564  8ea4ed4c-f037-47b3-8b2d-92c6037074a7          2020-07-09 09:20:01
# 6567  e3040ef1-99a3-4a75-8f89-06a5e4bc2e91          2020-09-10 19:34:24
# 6565  82ac415e-4933-4bae-9bdc-111b179b6277          2020-09-10 19:40:57
# 6568  40145004-6fa4-448a-b595-94df13ff73f5          2020-11-10 10:09:59
# 6569  4f0ba7ae-46ec-4cfd-86c4-83d2f9f95739          2020-11-12 14:38:38
# 6570  92fbba6c-402d-42ce-8329-0b4f8f47cfdb          2021-01-12 16:35:03
# 6571  8d5893fa-d322-4235-8a15-7d95703199bc          2021-01-12 16:36:39
# 6573  c1175acf-d2d0-4ffc-91c8-996b6044dac2          2021-07-28 16:36:04
# 6572  48cb21e0-9349-4589-bbae-d7b72b58f5e4          2021-07-28 16:45:58
# 6566  fc8a1b52-2045-4ad9-af0e-f72179962b68          2021-07-28 16:47:25
# 6577  d39c06a4-6168-40cc-aaa2-c38a2fd7df05          2021-12-06 11:13:29
# 6587  85cb76a6-32f7-4089-adff-8e04415908e8          2021-12-06 11:17:48
# 6574  eb22d274-ad4c-4947-ab82-96ff7f460f4f          2021-12-06 11:19:07
# 6576  864d00f6-7703-411f-a38c-b5ba16328a4f          2022-03-10 10:03:59
# 6575  f55ab453-6093-4792-a15a-f0b0937c69d6          2022-03-10 10:09:15
# 6583  0465638c-88cd-42c3-9b14-558d0ab34b51          2022-09-27 09:17:15
# 6581  0465638c-88cd-42c3-9b14-558d0ab34b51          2022-09-27 09:17:15
# 6582  0465638c-88cd-42c3-9b14-558d0ab34b51          2022-09-27 09:17:15
# 6586  aa5c37d5-d265-4648-b268-bfaa42c1efab          2022-09-27 09:19:12
# 6585  aa5c37d5-d265-4648-b268-bfaa42c1efab          2022-09-27 09:19:12
# 6584  aa5c37d5-d265-4648-b268-bfaa42c1efab          2022-09-27 09:19:12
# 6580  1aca73a1-a2e1-46ab-9082-5f3feaae7db3          2022-09-27 09:21:19
# 6579  1aca73a1-a2e1-46ab-9082-5f3feaae7db3          2022-09-27 09:21:19
# 6578  1aca73a1-a2e1-46ab-9082-5f3feaae7db3          2022-09-27 09:21:19
# 6588  5e8c2bf8-7757-4e12-94b5-9d8c9a7d2ebc          2023-12-13 17:25:06
# 6589  5e8c2bf8-7757-4e12-94b5-9d8c9a7d2ebc          2023-12-13 17:25:06
# 6590  5e8c2bf8-7757-4e12-94b5-9d8c9a7d2ebc          2023-12-13 17:25:06
# 6594  2543302f-b75b-4570-a9d0-b36cf6703405          2023-12-13 17:26:53
# 6595  2543302f-b75b-4570-a9d0-b36cf6703405          2023-12-13 17:26:53
# 6596  2543302f-b75b-4570-a9d0-b36cf6703405          2023-12-13 17:26:53
# 6591  30bcca0c-d92b-401f-a836-8fa4b7ab6b3f          2023-12-13 17:27:50
# 6592  30bcca0c-d92b-401f-a836-8fa4b7ab6b3f          2023-12-13 17:27:50
# 6593  30bcca0c-d92b-401f-a836-8fa4b7ab6b3f          2023-12-13 17:27:50
#
#      declarant_name declarant_surname declarant_birthdate  \
# 6564        LISNARD             DAVID          02/02/1969
# 6567        LISNARD             DAVID          02/02/1969
# 6565        LISNARD             DAVID          02/02/1969
# 6568        LISNARD             DAVID          02/02/1969
# 6569        LISNARD             DAVID          02/02/1969
# 6570        LISNARD             DAVID          02/02/1969
# 6571        LISNARD             DAVID          02/02/1969
# 6573        LISNARD             DAVID          02/02/1969
# 6572        LISNARD             DAVID          02/02/1969
# 6566        LISNARD             DAVID          02/02/1969
# 6577        LISNARD             DAVID          02/02/1969
# 6587        LISNARD             DAVID          02/02/1969
# 6574        LISNARD             DAVID          02/02/1969
# 6576        LISNARD             DAVID          02/02/1969
# 6575        LISNARD             DAVID          02/02/1969
# 6583        LISNARD             DAVID          02/02/1969
# 6581        LISNARD             DAVID          02/02/1969
# 6582        LISNARD             DAVID          02/02/1969
# 6586        LISNARD             DAVID          02/02/1969
# 6585        LISNARD             DAVID          02/02/1969
# 6584        LISNARD             DAVID          02/02/1969
# 6580        LISNARD             DAVID          02/02/1969
# 6579        LISNARD             DAVID          02/02/1969
# 6578        LISNARD             DAVID          02/02/1969
# 6588        LISNARD             DAVID          02/02/1969
# 6589        LISNARD             DAVID          02/02/1969
# 6590        LISNARD             DAVID          02/02/1969
# 6594        LISNARD             DAVID          02/02/1969
# 6595        LISNARD             DAVID          02/02/1969
# 6596        LISNARD             DAVID          02/02/1969
# 6591        LISNARD             DAVID          02/02/1969
# 6592        LISNARD             DAVID          02/02/1969
# 6593        LISNARD             DAVID          02/02/1969
#
#                                              nomSociete evaluation  \
# 6564                 SCI         [Données non publiées]        990
# 6567  SCI         [Données non publiées]            ...        990
# 6565  SCI        [Données non publiées]            [...        990
# 6568                 SCI         [Données non publiées]        990
# 6569  SCI         [Données non publiées]            ...        990
# 6570                 SCI         [Données non publiées]        990
# 6571  SCI         [Données non publiées]            ...        990
# 6573                  SCI        [Données non publiées]        990
# 6572                 SCI         [Données non publiées]        990
# 6566                  SCI        [Données non publiées]        990
# 6577                 SCI         [Données non publiées]        990
# 6587                 SCI         [Données non publiées]        990
# 6574                  SCI        [Données non publiées]        990
# 6576                 SCI         [Données non publiées]        990
# 6575                  SCI        [Données non publiées]        990
# 6583                                 ETOIL EUR AC 03 29       5022
# 6581                 SCI         [Données non publiées]        990
# 6582                                 ET ACT France C 4D      47857
# 6586                                 ETOIL EUR AC 03 29       5022
# 6585                                 ET ACT France C 4D      47857
# 6584                  SCI        [Données non publiées]        990
# 6580                                 ETOIL EUR AC 03 29       5022
# 6579                                 ET ACT France C 4D      47857
# 6578                 SCI         [Données non publiées]        990
# 6588                 SCI         [Données non publiées]        990
# 6589                                 ET ACT France C 4D      47857
# 6590                                 ETOIL EUR AC 03 29       5022
# 6594                 SCI         [Données non publiées]        990
# 6595                                 ET ACT France C 4D      47857
# 6596                                 ETOIL EUR AC 03 29       5022
# 6591                 SCI         [Données non publiées]        990
# 6592                                 ET ACT France C 4D      47857
# 6593                                 ETOIL EUR AC 03 29       5022
#
#      remuneration capitalDetenu nombreParts actiConseil  \
# 6564            0           100          99         NaN
# 6567            0           100          99         NaN
# 6565            0           100          99         NaN
# 6568            0           100          99         NaN
# 6569            0           100          99         NaN
# 6570            0           100          99         NaN
# 6571            0           100          99         NaN
# 6573            0           100          99         NaN
# 6572            0           100          99         NaN
# 6566            0           100          99         NaN
# 6577            0           100          99         NaN
# 6587            0           100          99         NaN
# 6574            0           100          99         NaN
# 6576            0           100          99         NaN
# 6575            0           100          99         NaN
# 6583            0          None          49         NaN
# 6581            0           100          99         NaN
# 6582            0          None        2368         NaN
# 6586            0          None          49         NaN
# 6585            0          None        2368         NaN
# 6584            0           100          99         NaN
# 6580            0          None          49         NaN
# 6579            0          None        2368         NaN
# 6578            0           100          99         NaN
# 6588            0           100          99         NaN
# 6589            0          None        2368         NaN
# 6590            0          None          49         NaN
# 6594            0           100          99         NaN
# 6595            0          None        2368         NaN
# 6596            0          None          49         NaN
# 6591            0           100          99         NaN
# 6592            0          None        2368         NaN
# 6593            0          None          49         NaN
#
#                                             commentaire  \
# 6564  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6567  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6565  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6568  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6569  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6570  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6571  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6573  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6572  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6566  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6577  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6587  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6574  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6576  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6575  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6583                         Valorisation au 31/12/2021
# 6581  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6582                         Valorisation au 31/12/2021
# 6586                         Valorisation au 31/12/2021
# 6585                         Valorisation au 31/12/2021
# 6584  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6580                         Valorisation au 31/12/2021
# 6579                         Valorisation au 31/12/2021
# 6578  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6588  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6589                         Valorisation au 31/12/2021
# 6590                         Valorisation au 31/12/2021
# 6594  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6595                         Valorisation au 31/12/2021
# 6596                         Valorisation au 31/12/2021
# 6591  Monsieur Lisnard est nue propriétaire de 99 pa...
# 6592                         Valorisation au 31/12/2021
# 6593                         Valorisation au 31/12/2021
#
#      nomOrganisationConseil       declarant_unique_id
# 6564                    NaN  LISNARD-DAVID-02/02/1969
# 6567                    NaN  LISNARD-DAVID-02/02/1969
# 6565                    NaN  LISNARD-DAVID-02/02/1969
# 6568                    NaN  LISNARD-DAVID-02/02/1969
# 6569                    NaN  LISNARD-DAVID-02/02/1969
# 6570                    NaN  LISNARD-DAVID-02/02/1969
# 6571                    NaN  LISNARD-DAVID-02/02/1969
# 6573                    NaN  LISNARD-DAVID-02/02/1969
# 6572                    NaN  LISNARD-DAVID-02/02/1969
# 6566                    NaN  LISNARD-DAVID-02/02/1969
# 6577                    NaN  LISNARD-DAVID-02/02/1969
# 6587                    NaN  LISNARD-DAVID-02/02/1969
# 6574                    NaN  LISNARD-DAVID-02/02/1969
# 6576                    NaN  LISNARD-DAVID-02/02/1969
# 6575                    NaN  LISNARD-DAVID-02/02/1969
# 6583                    NaN  LISNARD-DAVID-02/02/1969
# 6581                    NaN  LISNARD-DAVID-02/02/1969
# 6582                    NaN  LISNARD-DAVID-02/02/1969
# 6586                    NaN  LISNARD-DAVID-02/02/1969
# 6585                    NaN  LISNARD-DAVID-02/02/1969
# 6584                    NaN  LISNARD-DAVID-02/02/1969
# 6580                    NaN  LISNARD-DAVID-02/02/1969
# 6579                    NaN  LISNARD-DAVID-02/02/1969
# 6578                    NaN  LISNARD-DAVID-02/02/1969
# 6588                    NaN  LISNARD-DAVID-02/02/1969
# 6589                    NaN  LISNARD-DAVID-02/02/1969
# 6590                    NaN  LISNARD-DAVID-02/02/1969
# 6594                    NaN  LISNARD-DAVID-02/02/1969
# 6595                    NaN  LISNARD-DAVID-02/02/1969
# 6596                    NaN  LISNARD-DAVID-02/02/1969
# 6591                    NaN  LISNARD-DAVID-02/02/1969
# 6592                    NaN  LISNARD-DAVID-02/02/1969
# 6593                    NaN  LISNARD-DAVID-02/02/1969

# %% [markdown]
# ### Convert numbers to number types

# %%
# check remaining features to clean
complete_stocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11060 entries, 0 to 11059
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   declaration_uuid              11060 non-null  object
#  1   declaration_publication_date  11060 non-null  datetime64[ns]
#  2   declarant_name                11060 non-null  object
#  3   declarant_surname             11060 non-null  object
#  4   declarant_birthdate           11060 non-null  object
#  5   nomSociete                    11060 non-null  object
#  6   evaluation                    11060 non-null  int64
#  7   remuneration                  11060 non-null  object
#  8   capitalDetenu                 7011 non-null   float64
#  9   nombreParts                   11059 non-null  float64
#  10  actiConseil                   2752 non-null   object
#  11  commentaire                   4790 non-null   object
#  12  nomOrganisationConseil        82 non-null     object
#  13  declarant_unique_id           11060 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(10)
# memory usage: 1.2+ MB

# %%
complete_stocks_df.head(3)
# Out:
#                        declaration_uuid declaration_publication_date  \
# 0  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
# 1  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
# 2  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
#
#   declarant_name declarant_surname declarant_birthdate          nomSociete  \
# 0           ABAD            DAMIEN          05/04/1980              ORANGE
# 1           ABAD            DAMIEN          05/04/1980  CREDIT AGRICOLE SA
# 2           ABAD            DAMIEN          05/04/1980              AIRBUS
#
#    evaluation remuneration capitalDetenu  nombreParts actiConseil  \
# 0         877        néant          None         83.0         Non
# 1        2910        néant          None        341.0         Non
# 2        1929        NEANT          None         20.0         Non
#
#               commentaire nomOrganisationConseil     declarant_unique_id
# 0  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980
# 1  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980
# 2  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980

# %% [markdown]
# These features can be easily converted to numeric types:

# %%
complete_stocks_df['evaluation'] = pd.to_numeric(complete_stocks_df['evaluation'])

# %%
complete_stocks_df['nombreParts'] = pd.to_numeric(complete_stocks_df['nombreParts'])

# %%
complete_stocks_df['capitalDetenu'] = pd.to_numeric(complete_stocks_df['capitalDetenu'])

# %%
complete_stocks_df['nombreParts'] = pd.to_numeric(complete_stocks_df['nombreParts'])

# %% [markdown]
# The `remuneration` feature is fuzzy.
# We leave it raw.

# %%
complete_stocks_df['remuneration'].value_counts()
# Out:
# remuneration
# 0           5669
# Néant        214
# NEANT        154
# NS            95
# neant         85
#             ...
# 655            1
# 32 euros       1
# 481,81         1
# 398,05         1
# 762            1
# Name: count, Length: 2073, dtype: int64

# %% [markdown]
# ### Assign labels to string features

# %%
# check remaining features to clean
complete_stocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11060 entries, 0 to 11059
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   declaration_uuid              11060 non-null  object
#  1   declaration_publication_date  11060 non-null  datetime64[ns]
#  2   declarant_name                11060 non-null  object
#  3   declarant_surname             11060 non-null  object
#  4   declarant_birthdate           11060 non-null  object
#  5   nomSociete                    11060 non-null  object
#  6   evaluation                    11060 non-null  int64
#  7   remuneration                  11060 non-null  object
#  8   capitalDetenu                 7011 non-null   float64
#  9   nombreParts                   11059 non-null  float64
#  10  actiConseil                   2752 non-null   object
#  11  commentaire                   4790 non-null   object
#  12  declarant_unique_id           11060 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(9)
# memory usage: 1.1+ MB

# %%
complete_stocks_df.head(3)
# Out:
#                        declaration_uuid declaration_publication_date  \
# 0  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
# 1  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
# 2  4344aaa1-874d-4e6d-9b1a-45f7725b710c          2022-07-11 15:40:13
#
#   declarant_name declarant_surname declarant_birthdate          nomSociete  \
# 0           ABAD            DAMIEN          05/04/1980              ORANGE
# 1           ABAD            DAMIEN          05/04/1980  CREDIT AGRICOLE SA
# 2           ABAD            DAMIEN          05/04/1980              AIRBUS
#
#    evaluation remuneration  capitalDetenu  nombreParts actiConseil  \
# 0         877        néant            NaN         83.0         Non
# 1        2910        néant            NaN        341.0         Non
# 2        1929        NEANT            NaN         20.0         Non
#
#               commentaire nomOrganisationConseil     declarant_unique_id
# 0  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980
# 1  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980
# 2  [Données non publiées]                    NaN  ABAD-DAMIEN-05/04/1980

# %% [markdown]
# `actiConseil` is already clean enough:

# %%
complete_stocks_df.actiConseil.value_counts()
# Out:
# actiConseil
# Non    2670
# Oui      82
# Name: count, dtype: int64

# %% [markdown]
# `nomOrganisationConseil` is seldom used and doesn't bring valuable insights. We delete the feature.

# %%
complete_stocks_df.nomOrganisationConseil.value_counts()
# Out:
# nomOrganisationConseil
# [Données non publiées]                                                                              6
# aucune                                                                                              6
# Mediascop 100%                                                                                      4
# 0                                                                                                   4
# EILIS. 100% du capital détenu en tant que dirigeant fondateur non salarié de cette SASU.            3
# Selarl Pascale BORDES Avocate; je détiens 100 % des parts sociales, soit 100 % du capital social    3
# AMP CONSEILS LILLE 75% DU CAPITAL                                                                   2
# AMP CONSEILS AIX 60% DU CAPITAL                                                                     2
# MLEXPERT 100% DU CAPITAL                                                                            2
# SAS Renaissance                                                                                     2
# AMP CONSEILS MONTPELLIER 75% DU CAPITAL                                                             2
# sans objet                                                                                          2
# SAS PMH AVOCAT - Société à associé unique (une part détenue à 100%). Capital de départ 10000 €.     2
# Naegelen SAS                                                                                        2
# SCP SCHRECK                                                                                         2
# SELARL LA CLE DES CHAMPS                                                                            2
# neant                                                                                               2
# Inflexion Capital Partners SL, 100%                                                                 2
# AMP CONSEILS 99% du capital                                                                         2
# MESSIDOR                                                                                            2
# Cabinet ETSA, 1000 parts, 100%                                                                      2
# NFCONSULTING 900 parts, 90%.                                                                        2
# non connues                                                                                         2
# SCA Eglantine                                                                                       1
# Pylone                                                                                              1
# KNT IMMO100% des parts                                                                              1
# BIL CODE100% des parts du capital social100 parts                                                   1
# 100% DES PARTS SUR LE CAPITAL SOCIAL100 PARTS                                                       1
# NS                                                                                                  1
# MagellanConsulting                                                                                  1
# 1 part sociale dans EARL         [Données non publiées]                                             1
# paugetlefontonne                                                                                    1
# Piccolo                                                                                             1
# SARL        [Données non publiées]     Evaluation de 100 parts        [Données non publiées]        1
# Ephese                                                                                              1
# SCA Eglantine 209 parts                                                                             1
# Banque populaire                                                                                    1
# [Données non publiées]     1%                                                                       1
# SAS Anne Le Hénanff conseils et communication                                                       1
# 100%                                                                                                1
# GR FORESTIER         [Données non publiées]     21,55%                                              1
# SCI         [Données non publiées]     50% PP 40% Usufruit                                          1
# [Données non publiées]    1%         [Données non publiées]     1%                                  1
# KOSS NIQUEL TRAINING100 PARTS à 100% du capital                                                     1
# BARTHES CHRISTOPHE: 50,40% pour 2918,66 euros         [Données non publiées]                        1
# Name: count, dtype: int64

# %%
del complete_stocks_df['nomOrganisationConseil']

# %% [markdown]
# ## Upload dataset to the HUB
#
# Once clean and complete, we can safely upload the dataset to the HUB for further analysis.

# %%
from datasets import Dataset

complete_stocks_ds = Dataset.from_pandas(complete_stocks_df)

# %%
complete_stocks_ds
# Out:
# Dataset({
#     features: ['declaration_uuid', 'declaration_publication_date', 'declarant_name', 'declarant_surname', 'declarant_birthdate', 'nomSociete', 'evaluation', 'remuneration', 'capitalDetenu', 'nombreParts', 'actiConseil', 'commentaire', 'declarant_unique_id'],
#     num_rows: 11060
# })

# %%
complete_stocks_ds.push_to_hub("the-french-artist/hatvp_stock_participationFinanciereDto")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/12 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/the-french-artist/hatvp_stock_participationFinanciereDto/commit/ab607c6316d4cd75212305c9d8f3257b417b06c5', commit_message='Upload dataset', commit_description='', oid='ab607c6316d4cd75212305c9d8f3257b417b06c5', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Conclusion
#
# ## Some features are incomplete
#
# The following features have missing values:
# ````
# commentaire
# actiConseil
# capitalDetenu
# ````
#
# And `remuneration` is complete but contains fuzzy values (`32€` or `32 euros` or `32`, or `Néant`, etc...)

# %% [markdown]
# Next part here:
#
# https://colab.research.google.com/drive/1HNRCwOiMuZBy-e-y9pRSqUTPkRwNfpuK#scrollTo=DPgn2Ko6QhZ4
